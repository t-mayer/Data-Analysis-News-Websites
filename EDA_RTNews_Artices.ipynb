# %%
import pandas as pd
import numpy as np
import datetime
import collections
from dateutil.parser import parse
from collections import Counter, OrderedDict
from nltk.util import ngrams
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from plotly import tools
import plotly

# pandas options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# open pickled file
df = pd.read_pickle("./Cleaned_RT_News_new.pkl")

# drop empty articles: Convert NaN values to empty string
nan_value = float("NaN")
df.replace("", nan_value, inplace=True)
df.dropna(subset = ["Cleaned Article"], inplace=True)

# drop unncessary rows
df = df.drop(751)

# %%
# extend orginal df with columns about statistical properties of different topics/categories
columns = ['Word Count', 'Time','Date', 'BoW', 'Trigrams']
       
df = pd.concat([df,pd.DataFrame(columns=columns)])

# %%
# class ArticleStats has different methods:
# - word count: counts the words of an article
# - get_date: gets the publishing date of the article
# - get_time: gets the publishing date of the article
# - get_bow: creates a bag of words dict out of each article
# - get_trigrams: creates trigrams from article and stores them in a list

class ArticleStats:
    def __init__(self, df_data):
        self.df_data = df_data

    def word_count(self):
        
        # word count based on the cleaned article
        cleaned_article = self.df_data
        article_word_count = len(cleaned_article.split())
        return article_word_count
    
    def get_date(self):
        
        # time and date: clean, parse, extract
        date_time = self.df_data
        cleaned_date_time = date_time.replace('•', '').replace('Uhr', '')
        
        parse_date = parse(cleaned_date_time)
        
        date = parse_date.date()
        return date
    
    def get_time(self):
        
        # time and date: clean, parse, extract
        date_time = self.df_data
        cleaned_date_time = date_time.replace('•', '').replace('Uhr', '') 
        
        parse_time = parse(cleaned_date_time)
        
        time = parse_time.time()
        return time
    
    def get_bow(self):
        
        lemmas = self.df_data
        
        # Bow: counts word occurences, and returns ordered dictionary beginning with the most common
        bow = OrderedDict(Counter(lemmas).most_common())
        return bow
    
        
    def get_trigrams(self):
        
        cleaned_article = self.df_data
        
        # stores trigrams in a list
        trigrams_list = list(ngrams(cleaned_article.split(), 3))
        return trigrams_list


# apply ArticleStats methods to each row/article                 
df['Word Count'] = df['Cleaned Article'].apply(lambda row: ArticleStats(row).word_count())
df['Date'] = df['Date Published'].apply(lambda row: ArticleStats(row).get_date())
df['Time'] = df['Date Published'].apply(lambda row: ArticleStats(row).get_time()) 
df['BoW'] = df['Lemmas'].apply(lambda row: ArticleStats(row).get_bow()) 
df['Trigrams'] = df['Cleaned Article'].apply(lambda row: ArticleStats(row).get_trigrams()) 

df
# Out:
#                    News Site        Category  \
# 0     https://deutsch.rt.com    gesellschaft
# 1     https://deutsch.rt.com    gesellschaft
# 2     https://deutsch.rt.com    gesellschaft
# 3     https://deutsch.rt.com    gesellschaft
# 4     https://deutsch.rt.com    gesellschaft
# 5     https://deutsch.rt.com    gesellschaft
# 6     https://deutsch.rt.com    gesellschaft
# 7     https://deutsch.rt.com    gesellschaft
# 8     https://deutsch.rt.com    gesellschaft
# 9     https://deutsch.rt.com    gesellschaft
# 10    https://deutsch.rt.com    gesellschaft
# 11    https://deutsch.rt.com    gesellschaft
# 12    https://deutsch.rt.com    gesellschaft
# 13    https://deutsch.rt.com    gesellschaft
# 14    https://deutsch.rt.com    gesellschaft
# 15    https://deutsch.rt.com    gesellschaft
# 220   https://deutsch.rt.com          inland
# 221   https://deutsch.rt.com          inland
# 222   https://deutsch.rt.com          inland
# 223   https://deutsch.rt.com          inland
# 224   https://deutsch.rt.com          inland
# 225   https://deutsch.rt.com          inland
# 226   https://deutsch.rt.com          inland
# 227   https://deutsch.rt.com          inland
# 228   https://deutsch.rt.com          inland
# 229   https://deutsch.rt.com          inland
# 230   https://deutsch.rt.com          inland
# 231   https://deutsch.rt.com          inland
# 232   https://deutsch.rt.com          inland
# 233   https://deutsch.rt.com          inland
# 234   https://deutsch.rt.com          inland
# 235   https://deutsch.rt.com          inland
# 236   https://deutsch.rt.com          inland
# 237   https://deutsch.rt.com          inland
# 238   https://deutsch.rt.com          inland
# 239   https://deutsch.rt.com          inland
# 240   https://deutsch.rt.com          inland
# 241   https://deutsch.rt.com          inland
# 242   https://deutsch.rt.com          inland
# 243   https://deutsch.rt.com          inland
# 244   https://deutsch.rt.com          inland
# 245   https://deutsch.rt.com          inland
# 246   https://deutsch.rt.com          inland
# 247   https://deutsch.rt.com          inland
# 248   https://deutsch.rt.com          inland
# 250   https://deutsch.rt.com          inland
# 251   https://deutsch.rt.com          inland
# 252   https://deutsch.rt.com          inland
# 253   https://deutsch.rt.com          inland
# 255   https://deutsch.rt.com          inland
# 256   https://deutsch.rt.com          inland
# 257   https://deutsch.rt.com          inland
# 258   https://deutsch.rt.com          inland
# 259   https://deutsch.rt.com          inland
# 260   https://deutsch.rt.com          inland
# 261   https://deutsch.rt.com          inland
# 262   https://deutsch.rt.com          inland
# 263   https://deutsch.rt.com          inland
# 264   https://deutsch.rt.com          inland
# 265   https://deutsch.rt.com          inland
# 266   https://deutsch.rt.com          inland
# 267   https://deutsch.rt.com          inland
# 268   https://deutsch.rt.com          inland
# 269   https://deutsch.rt.com          inland
# 270   https://deutsch.rt.com          inland
# 271   https://deutsch.rt.com          inland
# 272   https://deutsch.rt.com          inland
# 273   https://deutsch.rt.com          inland
# 274   https://deutsch.rt.com          inland
# 275   https://deutsch.rt.com          inland
# 276   https://deutsch.rt.com          inland
# 277   https://deutsch.rt.com          inland
# 278   https://deutsch.rt.com          inland
# 279   https://deutsch.rt.com          inland
# 280   https://deutsch.rt.com          inland
# 281   https://deutsch.rt.com          inland
# 283   https://deutsch.rt.com          inland
# 284   https://deutsch.rt.com          inland
# 285   https://deutsch.rt.com          inland
# 286   https://deutsch.rt.com          inland
# 287   https://deutsch.rt.com          inland
# 288   https://deutsch.rt.com          inland
# 289   https://deutsch.rt.com          inland
# 290   https://deutsch.rt.com          inland
# 291   https://deutsch.rt.com          inland
# 292   https://deutsch.rt.com          inland
# 293   https://deutsch.rt.com          inland
# 294   https://deutsch.rt.com          inland
# 295   https://deutsch.rt.com          inland
# 296   https://deutsch.rt.com          inland
# 298   https://deutsch.rt.com          inland
# 299   https://deutsch.rt.com          inland
# 300   https://deutsch.rt.com          inland
# 301   https://deutsch.rt.com          inland
# 302   https://deutsch.rt.com          inland
# 303   https://deutsch.rt.com          inland
# 304   https://deutsch.rt.com          inland
# 979   https://deutsch.rt.com        russland
# 980   https://deutsch.rt.com        russland
# 981   https://deutsch.rt.com        russland
# 982   https://deutsch.rt.com        russland
# 983   https://deutsch.rt.com        russland
# 984   https://deutsch.rt.com        russland
# 985   https://deutsch.rt.com        russland
# 986   https://deutsch.rt.com        russland
# 987   https://deutsch.rt.com        russland
# 988   https://deutsch.rt.com        russland
# 989   https://deutsch.rt.com        russland
# 990   https://deutsch.rt.com        russland
# 991   https://deutsch.rt.com        russland
# 992   https://deutsch.rt.com        russland
# 993   https://deutsch.rt.com        russland
# 994   https://deutsch.rt.com        russland
# 995   https://deutsch.rt.com        russland
# 996   https://deutsch.rt.com        russland
# 997   https://deutsch.rt.com        russland
# 998   https://deutsch.rt.com        russland
# 999   https://deutsch.rt.com        russland
# 1000  https://deutsch.rt.com        russland
# 1001  https://deutsch.rt.com        russland
# 1002  https://deutsch.rt.com        russland
# 1003  https://deutsch.rt.com        russland
# 1004  https://deutsch.rt.com        russland
# 1005  https://deutsch.rt.com        russland
# 1006  https://deutsch.rt.com        russland
# 1007  https://deutsch.rt.com        russland
# 1008  https://deutsch.rt.com        russland
# 1009  https://deutsch.rt.com        russland
# 1010  https://deutsch.rt.com        russland
# 1011  https://deutsch.rt.com        russland
# 1012  https://deutsch.rt.com        russland
# 1013  https://deutsch.rt.com        russland
# 1014  https://deutsch.rt.com        russland
# ...
# 803   [(Nach, sechs, Jahren), (sechs, Jahren, akribi...
# 804   [(Die, USA, sollen), (USA, sollen, heute), (so...
# 805   [(Am, Mittwoch, hat), (Mittwoch, hat, der), (h...
# 806   [(Zu, diesem, Zeitpunkt), (diesem, Zeitpunkt, ...
# 807   [(Dass, Israel, seit), (Israel, seit, Jahren),...
# 808   [(In, den, vergangenen), (den, vergangenen, Ta...
# 809   [(In, einer, Zeit), (einer, Zeit, in), (Zeit, ...
# 810   [(Israel, und, die), (und, die, Vereinigten), ...
# 811   [(von, Karin, Leukefeld), (Karin, Leukefeld, D...
# 812   [(Den, Regenfällen, die), (Regenfällen, die, i...
# 813   [(David, Hale, stellvertretender), (Hale, stel...
# 814   [(Der, französische, Abgeordnete), (französisc...
# 815   [(Eine, Woche, nach), (Woche, nach, der), (nac...
# 816   [(Der, Libanon, brauche), (Libanon, brauche, t...
# 817   [(Die, Einigung, sei), (Einigung, sei, unter),...
# 818   [(Als, Antwort, auf), (Antwort, auf, eine), (a...
# 819   [(Seit, der, verheerenden), (der, verheerenden...
# 820   [(Der, USSonderbeauftragte, für), (USSonderbea...
# 821   [(Zuvor, hatten, bereits), (hatten, bereits, d...
# 822   [(Der, Sprecher, des), (Sprecher, des, russisc...
# 823   [(Viele, Libanesen, haben), (Libanesen, haben,...
# 824   [(Tausende, Menschen, versammelten), (Menschen...
# 825   [(Videos, in, den), (in, den, sozialen), (den,...
# 826   [(Am, Samstag, haben), (Samstag, haben, Tausen...
# 827   [(Wut, Trauer, und), (Trauer, und, neue), (und...
# 828   [(Die, aktuelle, Situation), (aktuelle, Situat...
# 829   [(von, Havva, Kökbudak), (Havva, Kökbudak, Wir...
# 830   [(Der, zweite, Offizier), (zweite, Offizier, d...
# 831   [(Die, Ursache, sei), (Ursache, sei, noch), (s...
# 832   [(Verschiedene, Quellen, in), (Quellen, in, de...
# 833   [(Der, Botschafter, teilte), (Botschafter, tei...
# 834   [(Im, Auftrag, der), (Auftrag, der, Bundesregi...
# 835   [(Die, starke, Detonation), (starke, Detonatio...
# 836   [(Die, Kosten, für), (Kosten, für, den), (für,...
# 837   [(Einem, Bericht, der), (Bericht, der, Nachric...
# 838   [(Am, August, fing), (August, fing, ein), (fin...
# 839   [(Nach, der, gewaltigen), (der, gewaltigen, De...
# 840   [(Eine, verheerende, Explosion), (verheerende,...
# 841   [(Die, synchronisierten, Clips), (synchronisie...
# 842   [(Im, Iran, gibt), (Iran, gibt, es), (gibt, es...
# 843   [(In, der, libanesischen), (der, libanesischen...
# 844   [(Plötzlich, spürten, wir), (spürten, wir, ein...
# 845   [(Der, Libanon, steckt), (Libanon, steckt, in)...
# 846   [(Nach, Aussage, eines), (Aussage, eines, isra...
# 847   [(Eine, heftige, Explosion), (heftige, Explosi...
# 848   [(Die, USRegierung, verfolgt), (USRegierung, v...
# 849   [(Die, Aussagen, über), (Aussagen, über, Feuer...
# 850   [(Nach, der, schweren), (der, schweren, Explos...
# 851   [(Hunderte, Menschen, seien), (Menschen, seien...
# 852   [(Wie, auf, zahlreichen), (auf, zahlreichen, F...
# 853   [(Der, libanesische, Außenminister), (libanesi...
# 854   [(Während, führende, UNBeamte), (führende, UNB...
# 855   [(SaudiArabien, verbuchte, für), (verbuchte, f...
# 856   [(Laut, der, Kinderrechtsorganisation), (der, ...
# 857   [(Dutzende, Feuerwehrleute, waren), (Feuerwehr...
# 858   [(Die, USA, haben), (USA, haben, Libyens), (ha...
# 859   [(Der, israelische, Premierminister), (israeli...
# 860   [(Das, israelische, Fernsehen), (israelische, ...
# 861   [(Die, regierungsfeindliche, Gruppierung), (re...
# 862   [(von, Zlatko, Percinic), (Zlatko, Percinic, D...
# 863   [(Seit, geraumer, Zeit), (geraumer, Zeit, läss...
# 864   [(Die, von, AfD), (von, AfD, und), (AfD, und, ...
# 865   [(Seit, mehreren, Monaten), (mehreren, Monaten...
# 866   [(Die, Regierung, in), (Regierung, in, Khartum...
# 867   [(Wieder, mal, typisch), (mal, typisch, Afrika...
# 868   [(Im, Sudan, wurde), (Sudan, wurde, ein), (wur...
# 869   [(Mit, scharfer, Kritik), (scharfer, Kritik, a...
# 870   [(Das, USAußenministerium, hat), (USAußenminis...
# 871   [(Es, sieht, danach), (sieht, danach, aus), (d...
# 872   [(Noch, vor, wenigen), (vor, wenigen, Wochen),...
# 873   [(Nachdem, der, Sprecher), (der, Sprecher, des...
# 874   [(Der, malische, Präsident), (malische, Präsid...
# 875   [(Eine, Quelle, der), (Quelle, der, Nachrichte...
# 876   [(Dickflüssiges, Öl, wird), (Öl, wird, ans), (...
# 877   [(Nach, weiterer, Gewalt), (weiterer, Gewalt, ...
# 878   [(Seit, Jahren, führen), (Jahren, führen, Nami...
# 879   [(Innenminister, Elkache, Alada), (Elkache, Al...
# 880   [(Vor, dem, Inselstaat), (dem, Inselstaat, Mau...
# 881   [(Das, südafrikanische, Bergbauunternehmen), (...
# 882   [(Seit, dem, Sturz), (dem, Sturz, des), (Sturz...
# 883   [(In, Südafrika, wurde), (Südafrika, wurde, ei...
# 884   [(Der, Krieg, in), (Krieg, in, Libyen), (in, L...
# 885   [(Im, Streit, um), (Streit, um, Afrikas), (um,...
# 886   [(Auch, nach, neun), (nach, neun, Jahren), (ne...
# 887   [(Die, Europäische, Weltraumorganisation), (Eu...
# 888   [(Gewinne, für, Großkonzerne), (für, Großkonze...
# 889   [(Die, wichtigsten, ausländischen), (wichtigst...
# 890   [(Nach, dem, am), (dem, am, Dienstag), (am, Di...
# 891   [(Seit, Monaten, fallen), (Monaten, fallen, Mi...
# 892   [(In, Äthiopien, ist), (Äthiopien, ist, es), (...
# 893   [(Seit, dem, Jahr), (dem, Jahr, baut), (Jahr, ...
# 894   [(Er, spricht, von), (spricht, von, einem), (v...
# 895   [(Es, sind, beeindruckende), (sind, beeindruck...
# 896   [(Sowohl, im, Kosovo), (im, Kosovo, als), (Kos...
# 897   [(Ägypten, hat, den), (hat, den, Sicherheitsra...
# 898   [(Seit, dem, ersten), (dem, ersten, Fund), (er...
# 899   [(Das, Verteidigungsministerium, bestätigte), ...
# 900   [(Am, Montag, hat), (Montag, hat, der), (hat, ...
# 901   [(Das, nordafrikanische, Land), (nordafrikanis...
# 902   [(Der, offizielle, Pressesprecher), (offiziell...
# 903   [(von, Timo, AlFarooq), (Timo, AlFarooq, Als),...
# 904   [(Auch, vor, den), (vor, den, Ländern), (den, ...
# 905   [(Die, OnlineAnhörung, per), (OnlineAnhörung, ...
# 906   [(Auch, im, ostafrikanischen), (im, ostafrikan...
# 907   [(Bei, der, weiblichen), (der, weiblichen, Gen...
# 908   [(Bei, dem, Liebhaber), (dem, Liebhaber, deuts...
# 909   [(Kuba, hat, zur), (hat, zur, Unterstützung), ...
# 910   [(Am, März, verkündete), (März, verkündete, di...
# 911   [(Eine, Reihe, afrikanischer), (Reihe, afrikan...
# 912   [(Piraten, haben, vor), (haben, vor, der), (vo...
# 913   [(Eine, aufgebrachte, Menschenmenge), (aufgebr...
# 914   [(In, Libyen, wütet), (Libyen, wütet, auch), (...
# 915   [(von, Kani, Tuyala), (Kani, Tuyala, Krisen), ...
# 916   [(In, ihrer, jüngsten), (ihrer, jüngsten, Meld...
# 918   [(Wie, die, Zeitung), (die, Zeitung, TchadInfo...
# 919   [(Es, war, der), (war, der, Innenminister), (d...
# 920   [(Die, von, der), (von, der, UN), (der, UN, an...
# 921   [(Das, Recyceln, dieses), (Recyceln, dieses, M...
# 922   [(Katastrophe, mit, Ansage), (mit, Ansage, Wäh...
# 923   [(von, Kani, Tuyala), (Kani, Tuyala, Mali), (T...
# 924   [(Der, Klimawandel, gilt), (Klimawandel, gilt,...
# 925   [(Dabei, bräuchte, das), (bräuchte, das, Land)...
# 926   [(Auf, der, LibyenKonferenz), (der, LibyenKonf...
# 927   [(Die, nationale, Ölgesellschaft), (nationale,...
# 928   [(Afrikas, größter, Handelspartner), (größter,...
# 929   [(Bei, einem, Auftritt), (einem, Auftritt, in)...
# 930   [(Aguila, Saleh, Issa), (Saleh, Issa, das), (I...
# 931   [(Der, türkische, und), (türkische, und, der),...
# 932   [(Die, Masernepidemie, in), (Masernepidemie, i...
# 933   [(Ein, Sprecher, von), (Sprecher, von, Haftars...
# 934   [(Angegriffen, wurde, der), (wurde, der, Flugp...
# 935   [(Das, türkische, Militär), (türkische, Militä...
# 936   [(Libyen, rückt, in), (rückt, in, den), (in, d...
# 937   [(Schwer, bewaffnete, Kämpfer), (bewaffnete, K...
# 938   [(Im, westafrikanischen, Binnenstaat), (westaf...
# 939   [(Im, Kampf, gegen), (Kampf, gegen, islamistis...
# 940   [(Vor, acht, Jahren), (acht, Jahren, bombardie...
# 941   [(Die, Polizei, sprach), (Polizei, sprach, zun...
# 942   [(Die, Weltgesundheitsorganisation, WHO), (Wel...
# 943   [(Sambias, Oberstes, Gericht), (Oberstes, Geri...
# 944   [(von, Kani, Tuyala), (Kani, Tuyala, Noch), (T...
# 945   [(Nach, aktuellen, Schätzungen), (aktuellen, S...
# 946   [(Das, Treffen, sollte), (Treffen, sollte, sic...
# 947   [(Sivillon, hatte, nach), (hatte, nach, Angabe...
# 948   [(Die, Polizei, ging), (Polizei, ging, gewalts...
# 949   [(Bei, dem, Absturz), (dem, Absturz, von), (Ab...
# 950   [(von, Kani, Tuyala), (Kani, Tuyala, Derzeit),...
# 951   [(Vor, wenigen, Tagen), (wenigen, Tagen, erst)...
# 952   [(So, schnell, wie), (schnell, wie, möglich), ...
# 953   [(Ein, Konvoi, der), (Konvoi, der, kanadischen...
# 954   [(Die, russische, MetPromGruppe), (russische, ...
# 955   [(Mutmaßliche, Islamisten, begannen), (Islamis...
# 956   [(Der, nigerianische, Präsident), (nigerianisc...
# 957   [(Südafrikas, Verteidigungsministerin, Nosiviw...
# 958   [(Afrikanische, Migranten, in), (Migranten, in...
# 959   [(Am, und, Oktober), (und, Oktober, findet), (...
# 961   [(Afrikas, erstes, Unternehmen), (erstes, Unte...
# 962   [(Am, Sonntag, landete), (Sonntag, landete, Bu...
# 963   [(Dieses, Jahr, wird), (Jahr, wird, die), (wir...
# 964   [(In, der, ersten), (der, ersten, Runde), (ers...
# 965   [(Ein, von, der), (von, der, South), (der, Sou...
# 966   [(Es, ist, erst), (ist, erst, das), (erst, das...
# 967   [(Südafrika, hat, eine), (hat, eine, Arbeitslo...
# 968   [(Nach, Übergriffen, gegen), (Übergriffen, geg...
# 969   [(Bei, einer, Explosion), (einer, Explosion, i...
# 970   [(Die, Verteidigung, der), (Verteidigung, der,...
# 971   [(Bei, einem, mutmaßlichen), (einem, mutmaßlic...
# 972   [(Das, chinesische, Militär), (chinesische, Mi...
# 973   [(Damit, widersetze, sich), (widersetze, sich,...
# 974   [(Peskow, erklärte, dass), (erklärte, dass, de...
# 975   [(Die, Ölpreise, fielen), (Ölpreise, fielen, a...
# 976   [(Unterdessen, ist, die), (ist, die, Phase), (...
# 977   [(Medienberichte, die, behaupten), (die, behau...
# 978   [(Nach, drei, aufeinanderfolgenden), (drei, au...
# 979   [(In, einer, am), (einer, am, Dienstag), (am, ...
# 980   [(Der, Schauspieler, Regisseur), (Schauspieler...
# 981   [(Laut, der, Erklärung), (der, Erklärung, des)...
# 982   [(Am, vergangenen, Mittwoch), (vergangenen, Mi...
# 983   [(Die, Pressesprecherin, des), (Pressesprecher...
# 984   [(Die, Ankündigung, der), (Ankündigung, der, R...
# 985   [(Die, deutschen, Behörden), (deutschen, Behör...
# 986   [(Sollten, sich, die), (sich, die, Information...
# 987   [(Die, Eigenschaften, des), (Eigenschaften, de...
# 988   [(Am, Donnerstag, hat), (Donnerstag, hat, der)...
# 989   [(Am, Donnerstag, hat), (Donnerstag, hat, der)...
# 990   [(Am, Donnerstag, hat), (Donnerstag, hat, der)...
# 991   [(Der, Botschafter, der), (Botschafter, der, R...
# 992   [(Der, Vorfall, ereignete), (Vorfall, ereignet...
# 993   [(Nach, der, Mitteilung), (der, Mitteilung, de...
# 994   [(Die, russische, Generalstaatsanwaltschaft), ...
# 995   [(Putins, ChefWirtschaftsberater, Maxim), (Che...
# 996   [(Russlands, Föderaler, Sicherheitsdienst), (F...
# 997   [(Wie, russische, Gesundheitsbehörden), (russi...
# 998   [(Am, Dienstag, kehren), (Dienstag, kehren, in...
# 999   [(Der, Blogger, und), (Blogger, und, Journalis...
# 1000  [(Im, Internet, ist), (Internet, ist, ein), (i...
# 1001  [(Die, Arktis, ist), (Arktis, ist, für), (ist,...
# 1002  [(Im, Kongress, und), (Kongress, und, Ausstell...
# 1003  [(Am, Freitag, wurde), (Freitag, wurde, der), ...
# 1004  [(Mitarbeiter, des, Russischen), (des, Russisc...
# 1005  [(Am, späten, Mittwochabend), (späten, Mittwoc...
# 1006  [(Beamte, der, Abteilung), (der, Abteilung, fü...
# 1007  [(Bei, den, betroffenen), (den, betroffenen, E...
# 1008  [(Vertreter, der, medizinischen), (der, medizi...
# 1009  [(Ab, Dienstag, sind), (Dienstag, sind, die), ...
# 1010  [(Washington, richtete, unter), (richtete, unt...
# 1011  [(Die, Streitkräfte, der), (Streitkräfte, der,...
# 1012  [(Am, Sonntag, sind), (Sonntag, sind, in), (si...
# 1013  [(Peskow, sagte, gegenüber), (sagte, gegenüber...
# 1014  [(Boris, Teplych, Chef), (Teplych, Chef, der),...
# 1015  [(Der, russische, Oppositionspolitiker), (russ...
# 1016  [(Nawalny, wird, derzeit), (wird, derzeit, in)...
# 1017  [(Im, Blut, und), (Blut, und, im), (und, im, U...
# 1018  [(An, Massentests, von), (Massentests, von, Ru...
# 1019  [(Anatoli, Kalinitschenko, stellvertretender),...
# 1020  [(Bei, der, Untersuchung), (der, Untersuchung,...
# 1021  [(Am, Donnerstagmorgen, berichtete), (Donnerst...
# 1022  [(Eine, Wertung, der), (Wertung, der, aktuelle...
# 1023  [(Die, Tragödie, ereignete), (Tragödie, ereign...
# 1024  [(Einige, Einwohner, der), (Einwohner, der, Re...
# 1025  [(Premierminister, Michail, Mischustin), (Mich...
# 1026  [(Der, Reservefonds, der), (Reservefonds, der,...
# 1027  [(Jim, Rogers, Gründer), (Rogers, Gründer, des...
# 1028  [(Der, Unruhestifter, betrat), (Unruhestifter,...
# 1029  [(Die, Bar, Trojnitschok), (Bar, Trojnitschok,...
# 1030  [(Wie, das, russische), (das, russische, Gesun...
# 1031  [(Der, russische, Gesundheitsminister), (russi...
# 1032  [(Das, Vakzin, wurde), (Vakzin, wurde, im), (w...
# 1033  [(Es, hätte, für), (hätte, für, Spartak), (für...
# 1034  [(Der, freie, Journalist), (freie, Journalist,...
# 1035  [(Der, russische, Präsident), (russische, Präs...
# 1036  [(Als, erstes, Land), (erstes, Land, der), (La...
# 1037  [(Nach, Angaben, von), (Angaben, von, Sergei),...
# 1038  [(Obwohl, die, russische), (die, russische, Wi...
# 1039  [(Ende, Juli, bekam), (Juli, bekam, ein), (bek...
# 1040  [(von, Leo, Ensel), (Leo, Ensel, Mit), (Ensel,...
# 1041  [(Sofja, Dorofejewa, ist), (Dorofejewa, ist, d...
# 1042  [(Während, der, CoronaPandemie), (der, CoronaP...
# 1043  [(Russland, hatte, seine), (hatte, seine, Gren...
# 1044  [(Ein, Gericht, der), (Gericht, der, Stadt), (...
# 1045  [(Nach, pandemiebedingten, Verzögerungen), (pa...
# 1046  [(Ljubow, Nurdinowa, aus), (Nurdinowa, aus, de...
# 1047  [(In, der, russischen), (der, russischen, Regi...
# 1048  [(Eine, Sonderarbeitsgruppe, der), (Sonderarbe...
# 1049  [(Die, russische, Gefängnisbehörde), (russisch...
# 1050  [(Die, klinischen, Tests), (klinischen, Tests,...
# 1051  [(Eine, Urlaubsreise, zum), (Urlaubsreise, zum...
# 1052  [(Wer, ein, mit), (ein, mit, dem), (mit, dem, ...
# 1053  [(Das, Unglück, ereignete), (Unglück, ereignet...
# 1054  [(Andy, Cartwright, der), (Cartwright, der, mi...
# 1055  [(Der, russische, Inslandsgeheimdienst), (russ...
# 1056  [(Laut, Angaben, der), (Angaben, der, Ermittle...
# 1057  [(Das, bizarre, diplomatische), (bizarre, dipl...
# 1058  [(Das, Verteidigungsministerium, gab), (Vertei...
# 1059  [(Die, Zeichentrickserie, Mascha), (Zeichentri...
# 1060  [(Das, russische, Staatliche), (russische, Sta...
# 1061  [(Russische, Unternehmen, könnten), (Unternehm...
# 1062  [(Wie, jeweils, am), (jeweils, am, letzten), (...
# 1063  [(Der, Föderale, Sicherheitsdienst), (Föderale...
# 1064  [(Ein, aussichtsreicher, ImpfstoffKandidat), (...
# 1065  [(Frage, Michail, Wladimirowitsch), (Michail, ...
# 1066  [(Russland, will, seinen), (will, seinen, Inla...
# 1067  [(Eine, Kindergärtnerin, aus), (Kindergärtneri...
# 1068  [(Der, russische, Premierminister), (russische...
# 1069  [(In, einer, am), (einer, am, Mittwoch), (am, ...
# 1070  [(Laut, Angaben, des), (Angaben, des, russisch...
# 1071  [(In, einem, Interview), (einem, Interview, mi...
# 1072  [(Aus, einer, Mitteilung), (einer, Mitteilung,...
# 1073  [(Wenn, wir, effizient), (wir, effizient, mit)...
# 1074  [(Das, entsprechende, Dekret), (entsprechende,...
# 1075  [(Gouverneur, Sergei, Furgal), (Sergei, Furgal...
# 1076  [(Ein, Staatsbürger, eines), (Staatsbürger, ei...
# 1077  [(Der, Gedenkmarsch, wurde), (Gedenkmarsch, wu...
# 1078  [(Wie, Iwan, Solowjow), (Iwan, Solowjow, Vorsi...
# 1079  [(Die, Teilnehmer, kamen), (Teilnehmer, kamen,...

# %%
# subset df to only have stats + category
df_stats = df[['Category','Word Count', 'Time','Date', 'BoW', 'Trigrams']]

# %%
# the Summarize class collapses BoW dictionaties and Trigram lists for each category
  
class Summarize:
    def __init__(self,df_data):
        self.df_data = df_data
     
    def sum_bow(self):
        
        # make a dictionary to collect data from all rows of a category
        bow_dict = {}
        
        # iterate through rows
        for ordered_dict in self.df_data:
        
            # check if word is already in common_dict
            for k, v in ordered_dict.items():

                # if not, add word and word count
                if k not in bow_dict:
                    bow_dict[k] = v

                # if yes, add word count to existing key/word
                else:
                    bow_dict[k] += v
                    
                    
        # return dictionary
        return bow_dict
    
    
    def sum_trigrams(self):
        
        # make a list to collect data from all rows of a category
        trigrams_list = []

        # iterate through rows of df
        for trigram in self.df_data:
            
            # append trigram to list
            trigrams_list.append(trigram)
    
        #flatten list  
        trigrams_list = sum(trigrams_list, [])
        
        # returns a list of all trigrams within one category
        return trigrams_list
        


    
# make 2 new dataframes for BoW and Trigrams
columns_bow = ['Category','Most common word','Count Word']
columns_trigram = ['Category','Most common trigram','Count Trigram']

bow_df = pd.DataFrame(columns=columns_bow)
trigram_df = pd.DataFrame(columns=columns_trigram)


# iterate through the rows of the 10 categories and apply class methods
for category in df['Category'].unique():
    
    # list of bows for one category
    bow_dict = Summarize(df_stats[df_stats['Category']==category]['BoW']).sum_bow()
    
    # get the most common 20 bows for one category
    most_common_bow = dict(Counter(bow_dict).most_common(20))
    
    # list of trigram for one category
    trigrams = Summarize(df_stats[df_stats['Category']==category]['Trigrams']).sum_trigrams()
    
    # get the most common 20 trigrams for one category
    most_common_tri = dict(Counter(trigrams).most_common(20))

    
    # append bows, counts, and category to list and fill df row-wise
    for k, v in most_common_bow.items():
        list_bow_info = []
        list_bow_info.append(category)
        list_bow_info.append(k)
        list_bow_info.append(v)
        
        bow_df.loc[len(bow_df)] = list_bow_info
        
    # append trigrams, counts, and category to list and fill df row-wise    
    for k1, v1 in most_common_tri.items():
        list_trigram_info = []
        list_trigram_info.append(category)
        list_trigram_info.append(' '.join([str(x) for x in k1]))
        list_trigram_info.append(v1)
                
        trigram_df.loc[len(trigram_df)] = list_trigram_info

# %%
# Visualize word count of RT News Articles

fig = go.Figure()
fig.add_trace(go.Histogram(x=df_stats['Word Count'],
                           
                            # bins used for histogram
                           xbins=dict(start=1, end=df_stats['Word Count'].max(), size=100), marker_color='#41bd95'))




fig.update_layout(
    title_text='<b>Word Count of RT News Articles (German)</b>', # title of plot
    xaxis_title_text='<b>Word Count</b>', # xaxis label
    yaxis_title_text='<b>Article Count</b>', # yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.
 156, 189, 289, 330, 398, 1004, 414, 212, 176, 406, 136, 498, 203, 309, 395, 293, 266, 208, 405, 466, 1268, 332, 168, 337, 191, 265, 288, 213, 987, 148, 234, 928, 664, 173, 431, 1299, 228, 171, 330, 1295, 263, 1197, 245, 303, 311, 247, 355, 174, 347, 155, 860, 419, 1371, 111, 714, 696, 481, 473, 196, 1478, 173, 396, 274, 485, 1363, 1012, 644, 265, 1538, 444, 194, 222, 288, 1171, 142, 52, 676, 583, 259, 332, 185, 528, 600, 1240, 1193, 291, 39, 214, 282, 355, 236, 204, 382, 385, 1186, 786, 181, 107, 380, 1001, 39, 285, 958, 24, 1818, 616, 254, 40, 1318, 162, 196, 784, 383, 2014, 258, 283, 338, 383, 384, 222, 701, 1191, 356, 361, 797, 296, 17, 472, 311, 15, 24, 367, 307, 285, 383, 404, 175, 444, 208, 20, 327, 66, 456, 495, 397, 565, 306, 318, 513, 685, 396, 211, 828, 739, 282, 528, 450, 263, 633, 541, 433, 324, 282, 358, 91, 983, 194, 554, 718, 132, 708, 353, 480, 275, 610, 278, 551, 223, 852, 232, 301, 632, 417, 676, 736, 579, 277, 237, 447, 251, 153, 325, 373, 369, 157, 297, 300, 278, 292, 184, 238, 465, 431, 327, 287, 961, 529, 1013, 291, 333, 403, 385, 33, 233, 410, 472, 304, 584, 441, 396, 305, 492, 739, 228, 495, 214, 395, 546, 319, 18, 434, 416, 274, 221, 226, 261, 997, 473, 352, 201, 59, 554, 62, 30, 453, 286, 27, 409, 370, 121, 308, 862, 391, 177, 647, 394, 191, 325, 320, 192, 409, 109, 660, 179, 159, 98, 1174, 326, 199, ...

# %%
# Visuliaze: word count by category
gesellschaft = df_stats[df_stats['Category']=='gesellschaft']['Word Count']
wirtschaft = df_stats[df_stats['Category']=='wirtschaft']['Word Count']
inland = df_stats[df_stats['Category']=='inland']['Word Count']
asien = df_stats[df_stats['Category']=='asien']['Word Count']
amerika = df_stats[df_stats['Category']=='amerika']['Word Count']
nordamerika = df_stats[df_stats['Category']=='nordamerika']['Word Count']
europa = df_stats[df_stats['Category']=='europa']['Word Count']
der_nahe_osten = df_stats[df_stats['Category']=='der-nahe-osten']['Word Count']
afrika = df_stats[df_stats['Category']=='afrika']['Word Count']
russland = df_stats[df_stats['Category']=='russland']['Word Count']


fig = make_subplots(rows=5, cols=2, vertical_spacing=0.1)

gesellschaft = go.Histogram(x=gesellschaft,
                      xbins=dict(start=1, end=df_stats['Word Count'].max(), size=100),
                      autobinx=False, name='Gesellschaft')

wirtschaft = go.Histogram(x=wirtschaft,
                      xbins=dict(start=1, end=df_stats['Word Count'].max(), size=100),
                      autobinx=False, name='Wirtschaft')

inland = go.Histogram(x=inland,
                      xbins=dict(start=1, end=df_stats['Word Count'].max(), size=100),
                      autobinx=False, name='Inland')

asien = go.Histogram(x=asien,
                      xbins=dict(start=1, end=df_stats['Word Count'].max(), size=100),
                      autobinx=False, name='Asien')

amerika = go.Histogram(x=amerika,
                      xbins=dict(start=1, end=df_stats['Word Count'].max(), size=100),
                      autobinx=False, name='Amerika')

nordamerika = go.Histogram(x=nordamerika,
                      xbins=dict(start=1, end=df_stats['Word Count'].max(), size=100),
                      autobinx=False, name='Nordamerika')

europa = go.Histogram(x=europa,
                      xbins=dict(start=1, end=df_stats['Word Count'].max(), size=100),
                      autobinx=False, name='Europa')

der_nahe_osten = go.Histogram(x=der_nahe_osten,
                      xbins=dict(start=1, end=df_stats['Word Count'].max(), size=100),
                      autobinx=False, name='Der nahe Osten')

afrika = go.Histogram(x=afrika,
                      xbins=dict(start=1, end=df_stats['Word Count'].max(), size=100),
                      autobinx=False, name='Afrika')

russland = go.Histogram(x=russland,
                      xbins=dict(start=1, end=df_stats['Word Count'].max(), size=100),
                      name='Russland')       

fig.update_yaxes(title_text='<b>Article Count</b>', range=[0, 40])
fig.update_xaxes(title_text='<b>Word Count</b>', range=[1, 5000])




fig.append_trace(gesellschaft, 1, 1)
fig.append_trace(wirtschaft, 1, 2)
fig.append_trace(amerika, 2, 1)
fig.append_trace(nordamerika, 2, 2)
fig.append_trace(der_nahe_osten, 3, 1)
fig.append_trace(afrika, 3, 2)
fig.append_trace(russland, 4, 1)
fig.append_trace(europa, 4, 2)
fig.append_trace(inland, 5, 1)
fig.append_trace(asien, 5, 2)



fig.update_layout(height=1000, width=1000,
                  title_text='<b>Word Count of RT News Articles (German) by Category</b>', # title of plot
                  # gap between bars of adjacent location coordinates
                  bargap=0.2,
                  # gap between bars of the same location coordinates
                  bargroupgap=0.1)


fig.show()
# Out:
# <div>                            <div id="a0b58ae1-fb08-4122-8ad8-a6dfaef5537c" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0b58ae1-fb08-4122-8ad8-a6dfaef5537c")) {                    Plotly.newPlot(                        "a0b58ae1-fb08-4122-8ad8-a6dfaef5537c",                        [{"autobinx": false, "name": "Gesellschaft", "type": "histogram", "x": [943, 342, 223, 36, 136, 157, 355, 4662, 139, 414, 51, 334, 474, 519, 278, 40, 327, 141, 451, 335, 542, 17, 359, 513, 4877, 2098, 475, 20, 500, 200, 512, 4837, 302, 734, 243, 342, 299, 259, 380, 526, 165, 198, 117, 883, 3349, 233, 779, 227, 82, 399, 186, 208, 4014, 297, 324, 143, 212, 353, 305, 78, 186, 481, 265, 306, 34, 434, 266, 183, 2598, 852, 668, 334, 295, 288, 294, 418, 851, 417, 290, 600, 290, 654, 452, 172, 862, 398, 409, 638, 262, 766, 238, 471, 74, 78, 174, 573, 782, 27, 975, 367, 1016, 186, 356, 481, 67, 347, 721], "xaxis": "x", "xbins": {"end": 4877, "size": 100, "start": 1}, "yaxis": "y"}, {"autobinx": false, "name": "Wirtschaft", "type": "histogram", "x": [426, 495, 520, 355, 313, 772, 335, 257, 299, 317, 389, 190, 164, 569, 529, 467, 464, 219, 238, 161, 214, 524, 247, 390, 351, 393, 292, 302, 148, 389, 242, 338, 305, 116, 576, 96, 281, 314, 509, 242, 65, 397, 152, 507, 207, 340, 197, 416, 287, 268, 663, 257, 412, 338, 1200, 249, 223, 253, 447, 363, 189, 146, 259, 189, 281, 284, 291, 204, 325, 247, 303, 300, 552, 150, 311, 249, 827, 288, 384, 230, 653, 614, 342, 202, 341, 234, 234, 238, 262, 392, 186, 578, 284, 331, 340, 202, 237, 317, 29, 451, 288, 449, 314, 627, 263, 252, 327], "xaxis": "x2", "xbins": {"end": 4877, "size": 100, "start": 1}, "yaxis": "y2"}, {"autobinx": false, "name": "Amerika", "type": "histogram", "x": [136, 498, 203, 309, 395, 293, 266, 208, 405, 466, 1268, 332, 168, 337, 191, 265, 288, 213, 987, 148, 234, 928, 664, 173, 431, 1299, 228, 171, 330, 1295, 263, 1197, 245, 303, 311, 247, 355, 174, 347, 155, 860, 419, 1371, 111, 714, 696, 481, 473, 196, 1478, 173, 396, 274, 485, 1363, 1012, 644, 265, 1538, 444, 194, 222, 288, 1171, 142, 52, 676, 583, 259, 332, 185, 528, 600, 1240, 1193, 291, 39, 214, 282, 355, 236, 204, 382, 385, 1186, 786, 181, 107, 380, 1001, 39, 285, 958, 24, 1818, 616, 254, 40, 1318, 162, 196, 784, 383, 2014, 258, 283], "xaxis": "x3", "xbins": {"end": 4877, "size": 100, "start": 1}, "yaxis": "y3"}, {"autobinx": false, "name": "Nordamerika", "type": "histogram", "x": [338, 383, 384, 222, 701, 1191, 356, 361, 797, 296, 17, 472, 311, 15, 24, 367, 307, 285, 383, 404, 175, 444, 208, 20, 327, 66, 456, 495, 397, 565, 306, 318, 513, 685, 396, 211, 828, 739, 282, 528, 450, 263, 633, 541, 433, 324, 282, 358, 91, 983, 194, 554, 718, 132, 708, 353, 480, 275, 610, 278, 551, 223, 852, 232, 301, 632, 417, 676, 736, 579, 277, 237, 447, 251, 153, 325, 373, 369, 157, 297, 300, 278, 292, 184, 238, 465, 431, 327, 287, 961, 529, 1013, 291, 333, 403, 385, 33, 233, 410, 472, 304, 584, 441, 396, 305, 492], "xaxis": "x4", "xbins": {"end": 4877, "size": 100, "start": 1}, "yaxis": "y4"}, {"autobinx": false, "name": "Der nahe Osten", "type": "histogram", "x": [405, 128, 264, 580, 476, 889, 194, 512, 690, 448, 257, 227, 452, 349, 363, 125, 214, 242, 674, 496, 187, 153, 353, 554, 328, 477, 369, 515, 1787, 211, 556, 163, 337, 407, 193, 153, 551, 1227, 398, 1135, 490, 175, 243, 1185, 381, 487, 126, 417, 52, 408, 193, 891, 636, 1860, 649, 91, 367, 1071, 376, 421, 471, 954, 707, 337, 170, 373, 468, 38, 318, 252, 27, 1195, 238, 95, 214, 271, 296, 350, 115, 261, 310, 725, 322, 126, 710, 247, 104, 123, 116, 88, 124, 117, 111, 102, 208, 281, 803, 291, 447, 557, 262, 193, 313, 1298, 1261, 524], "xaxis": "x5", "xbins": {"end": 4877, "size": 100, "start": 1}, "yaxis": "y5"}, {"autobinx": false, "name": "Afrika", "type": "his ...

# %%
# Visulize: average word count by category

# extract average word count from df_stats and categories and append to list
category_list = df_stats['Category'].unique()

means =[]
categories= []

for category in category_list:
    mean = df[df_stats['Category']==category]['Word Count'].mean()
    means.append(mean)
    categories.append(category)
  

fig = px.bar(y=means, x=categories)

fig.update_traces(marker_color='#41bd57')
fig.update_layout(
    title_text='<b>Average Word Count of RT News Articles (German) by Category</b>', # title of plot
    xaxis_title_text='<b>Categories</b>', # xaxis label
    yaxis_title_text='<b>Average Word Count</b>', #yaxis label
    bargap=0.2, # gap between bars of adjacent location coordinates
    bargroupgap=0.1 # gap between bars of the same location coordinates
)

fig.show()
# Out:
# <div>                            <div id="457754ac-1226-4214-b9e7-2e0dca178b72" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("457754ac-1226-4214-b9e7-2e0dca178b72")) {                    Plotly.newPlot(                        "457754ac-1226-4214-b9e7-2e0dca178b72",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#41bd57"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["gesellschaft", "wirtschaft", "inland", "asien", "amerika", "nordamerika", "europa", "der-nahe-osten", "afrika", "russland"], "xaxis": "x", "y": [587.2897196261682, 336.30841121495325, 396.19417475728153, 271.99074074074076, 502.311320754717, 402.87735849056605, 424.8878504672897, 428.97169811320754, 436.0660377358491, 336.6574074074074], "yaxis": "y"}],                        {"bargap": 0.2, "bargroupgap": 0.1, "barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, " ...

# %%
# Visualize: time of publication 

# extract hour of publication
hour = pd.to_datetime(df_stats['Time'], format='%H:%M:%S').dt.hour



fig = go.Figure()
fig.add_trace(go.Histogram(x=hour,
                            # bins used for histogram
                           xbins=dict(start=hour.min(), end=hour.max(), size=1), marker_color='#bd4169'
))


fig.update_layout(
    title_text='<b>Hour of Publication of RT News Articles (German)</b>', # title of plot
    xaxis_title_text='<b>Hour</b>', # xaxis label
    yaxis_title_text='<b>Article Count</b>',
    bargap=0.1, # gap between bars of adjacent location coordinates
    bargroupgap=0.1 # gap between bars of the same location coordinates
)

fig.show()
# Out:
# <div>                            <div id="2ea66835-0493-4e3f-98df-0eecadd363e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ea66835-0493-4e3f-98df-0eecadd363e8")) {                    Plotly.newPlot(                        "2ea66835-0493-4e3f-98df-0eecadd363e8",                        [{"marker": {"color": "#bd4169"}, "type": "histogram", "x": [22, 19, 11, 16, 11, 17, 7, 17, 8, 21, 17, 6, 21, 6, 17, 19, 17, 6, 22, 6, 10, 8, 16, 7, 18, 6, 6, 18, 17, 7, 12, 21, 8, 6, 8, 6, 21, 17, 11, 9, 18, 9, 18, 11, 18, 22, 11, 17, 19, 6, 7, 9, 19, 17, 12, 19, 18, 17, 10, 18, 22, 22, 17, 15, 14, 11, 9, 8, 21, 15, 8, 13, 11, 6, 9, 8, 12, 7, 7, 7, 10, 6, 19, 12, 6, 17, 20, 22, 10, 8, 6, 14, 13, 21, 17, 13, 11, 19, 6, 8, 17, 8, 12, 11, 18, 20, 6, 6, 9, 7, 6, 7, 6, 11, 6, 6, 7, 16, 8, 11, 6, 13, 7, 20, 9, 6, 6, 6, 19, 6, 22, 17, 10, 7, 6, 15, 12, 21, 13, 6, 22, 19, 12, 6, 14, 12, 7, 19, 10, 6, 6, 9, 22, 6, 8, 6, 17, 8, 8, 20, 12, 11, 6, 7, 6, 17, 6, 14, 7, 20, 6, 6, 10, 7, 20, 6, 10, 6, 8, 10, 6, 6, 12, 10, 13, 15, 7, 14, 13, 6, 10, 6, 12, 8, 6, 6, 14, 15, 7, 
 15, 10, 7, 7, 11, 9, 21, 20, 20, 19, 18, 15, 20, 18, 17, 14, 10, 22, 21, 18, 13, 13, 8, 6, 21, 19, 17, 15, 15, 9, 16, 14, 11, 11, 13, 12, 16, 7, 10, 14, 8, 22, 14, 12, 12, 7, 8, 20, 16, 12, 21, 21, 20, 15, 13, 21, 21, 14, 11, 23, 11, 6, 6, 20, 16, 13, 19, 10, 8, 21, 8, 19, 20, 15, 11, 10, 6, 18, 17, 14, 17, 14, 13, 8, 7, 20, 20, 16, 14, 10, 6, 19, 17, 20, 19, 19, 16, 7, 2, 19, 18, 6, 19, 12, 15, 14, 12, 23, 18, 10, 22, 20, 19, 16, 14, 12, 10, 6, 1, 1, 22, 22, 21, 20, 19, 19, 19, 18, 16, 7, 15, 6, 14, 19, 15, 16, 10, 12, 16, 20, 7, 21, 16, 11, 19, 11, 21, 19, 12, 10, 18, 9, 19, 14, 12, 14, 7, 8, 20, 16, 6, 8, 6, 14, 18, 14, 12, 21, 14, 11, 8, 13, 12, 6, 8, 6, 21, 9, 9, 13, 8, 13, 6, 11, 12, 17, 12, 10, 13, 10, 21, 14, 11, 6, 14, 6, 8, 20, 17, 8, 14, 17, 21, 16, 18, 10, 8, 16, 22, 14, 6, 13, 13, 15, 10, 9, 10, 7 ...

# %%
# Viualize: Bag-of-words by category
gesellschaft = bow_df[bow_df['Category'] == 'gesellschaft']
wirtschaft = bow_df[bow_df['Category'] == 'wirtschaft']
inland =  bow_df[bow_df['Category'] == 'inland']
asien =  bow_df[bow_df['Category'] == 'asien']
amerika =  bow_df[bow_df['Category'] == 'amerika']
nordamerika = bow_df[bow_df['Category'] == 'nordamerika']
europa =  bow_df[bow_df['Category'] == 'europa']
der_nahe_osten =  bow_df[bow_df['Category'] == 'der-nahe-osten']
afrika =  bow_df[bow_df['Category'] == 'afrika']
russland =  bow_df[bow_df['Category'] == 'russland']


gesellschaft = go.Bar(y=gesellschaft['Most common word'], x=gesellschaft['Count Word'],
            marker=dict(color="#f3f416"), orientation='h', name='Gesellschaft')

wirtschaft = go.Bar(y=wirtschaft['Most common word'], x=wirtschaft['Count Word'],
            marker=dict(color="#19d4c6"), orientation='h', name='Wirtschaft')

inland = go.Bar(y=inland['Most common word'], x=inland['Count Word'],
            marker=dict(color="#211bc9"), orientation='h', name='Inland')

asien = go.Bar(y=asien['Most common word'], x=asien['Count Word'],
            marker=dict(color="#b416c7"), orientation='h', name='Asien')

amerika = go.Bar(y=amerika['Most common word'], x=amerika['Count Word'],
            marker=dict(color="#ec8c16"), orientation='h', name='Amerika')

nordamerika = go.Bar(y=nordamerika['Most common word'], x=nordamerika['Count Word'],
            marker=dict(color="#b26363"), orientation='h',name='Nordamerika')

europa = go.Bar(y=europa['Most common word'],x=europa['Count Word'],
            marker=dict(color="#20d62c"), orientation='h', name='Europa')

der_nahe_osten = go.Bar(y=der_nahe_osten['Most common word'], x=der_nahe_osten['Count Word'],
            marker=dict(color="#d41763"), orientation='h', name='Der nahe Osten')

afrika = go.Bar(y=afrika['Most common word'], x=afrika['Count Word'],
            marker=dict(color="#a72727"), orientation='h', name='Afrika')

russland = go.Bar(y=russland['Most common word'], x=russland['Count Word'],
            marker=dict(color="#458b74"), orientation='h', name='Russland')




fig = plotly.subplots.make_subplots(rows=10, cols=1)

fig.append_trace(gesellschaft, 1,1)
fig.append_trace(wirtschaft, 2, 1)
fig.append_trace(inland, 3,1)
fig.append_trace(europa, 4, 1)
fig.append_trace(asien, 5,1)
fig.append_trace(der_nahe_osten, 6, 1)
fig.append_trace(russland, 7,1)
fig.append_trace(nordamerika, 8, 1)
fig.append_trace(amerika, 9,1)
fig.append_trace(afrika, 10, 1)


fig.update_yaxes(title_text='<b>Most common Words</b>')
fig.update_xaxes(title_text='<b>Word Count</b>')

fig.update_layout(height=5000, width=1000,
                  title_text='<b>Most common Words of RT News Articles (German) by Category</b>', # title of plot
                  # gap between bars of adjacent location coordinates
                  bargap=0.2,
                  # gap between bars of the same location coordinates
                  bargroupgap=0.01)




fig.show()
# Out:
# <div>                            <div id="9a02b723-27eb-4fc6-93ac-81d16e9c0146" class="plotly-graph-div" style="height:5000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a02b723-27eb-4fc6-93ac-81d16e9c0146")) {                    Plotly.newPlot(                        "9a02b723-27eb-4fc6-93ac-81d16e9c0146",                        [{"marker": {"color": "#f3f416"}, "name": "Gesellschaft", "orientation": "h", "type": "bar", "x": [464, 281, 238, 163, 153, 145, 141, 138, 123, 121, 116, 109, 94, 88, 86, 81, 80, 79, 77, 75], "xaxis": "x", "y": ["sein", "werden", "geben", "Jahr", "Mensch", "sagen", "mehr", "Kind", "gehen", "k\u00f6nnen", "kommen", "viel", "Virus", "sehen", "ganz", "m\u00fcssen", "haben", "Ma\u00dfnahme", "immer", "Test"], "yaxis": "y"}, {"marker": {"color": "#19d4c6"}, "name": "Wirtschaft", "orientation": "h", "type": "bar", "x": [248, 221, 157, 131, 115, 113, 107, 98, 95, 94, 86, 84, 79, 68, 68, 64, 63, 62, 59, 59], "xaxis": "x2", "y": ["Prozent", "Jahr", "Unternehmen", "werden", "China", "USDollar", "Milliarde", "Million", "sagen", "sein", "Land", "USA", "gro\u00df", "geben", "Euro", "Tag", "pro", "mehr", "seit", "Monat"], "yaxis": "y2"}, {"marker": {"color": "#211bc9"}, "name": "Inland", "orientation": "h", "type": "bar", "x": [221, 210, 129, 110, 103, 102, 94, 76, 74, 73, 68, 66, 65, 63, 62, 62, 61, 61, 61, 60], "xaxis": "x3", "y": ["sein", "werden", "Polizei", "sagen", "Mensch", "geben", "Berlin", "mehr", "Deutschland", "Nawalny", "erkl\u00e4ren", "m\u00fcssen", "Kind", "Jahr", "Bundesregierung", "kommen", "Prozent", "Fall", "Berliner", "haben"], "yaxis": "y3"}, {"marker": {"color": "#20d62c"}, "name": "Europa", "orientation": "h", "type": "bar", "x": [288, 210, 131, 126, 125, 106, 90, 87, 83, 82, 81, 81, 81, 79, 76, 71, 67, 67, 66, 66], "xaxis": "x4", "y": ["werden", "sein", "Land", "geben", "sagen", "Jahr", "Nawalny", "Regierung", "T\u00fcrkei", "Russland", "Mensch", "seit", "Pr\u00e4sident", "russisch", "Lukaschenko", "kommen", "gehen", "t\u00fcrkisch", "erkl\u00e4ren", "deutsch"], "yaxis": "y4"}, {"marker": {"color": "#b416c7"}, "name": "Asien", "orientation": "h", "type": "bar", "x": [202, 202, 113, 104, 96, 90, 88, 84, 76, 63, 62, 60, 57, 55, 54, 51, 49, 49, 49, 48], "xaxis": "x5", "y": ["werden", "China", "Land", "Jahr", "sein", "Indien", "chinesisch", "USA", "indisch", "Peking", "Mensch", "chinesische", "geben", "mehr", "Prozent", "sollen", "erkl\u00e4ren", "seit", "beid", "weit"], "yaxis": "y5"}, {"marker": {"color": "#d41763"}, "name": "Der nahe Osten", "orientation": "h", "type": "bar", "x": [339, 227, 166, 164, 161, 153, 145, 144, 129, 117, 117, 112, 112, 104, 103, 100, 83, 83, 82, 82], "xaxis": "x6", "y": ["werden", "Israel", "sein", "Land", "Libanon", "Explosion", "Beirut", "Iran", "Jahr", "seit", "T\u00fcrkei", "sagen", "Syrien", "Regierung", "USA", "the", "Mensch", "geben", "Hafen", "Pr\u00e4sident"], "yaxis": "y6"}, {"marker": {"color": "#458b74"}, "name": "Russland", "orientation": "h", "type": "bar", "x": [327, 183, 137, 135, 132, 107, 94, 90, 87, 82, 79, 78, 71, 68, 61, 60, 59, 58, 58, 53], "xaxis": "x7", "y": ["werden", "russisch", "Jahr", "sein", "Russland", "russische", "Impfstoff", "geben", "sagen", "Moskau", "Land", "Nawalny", "bereits", "Arzt", "sollen", "deutsch", "Mensch", "mehr", "erst", "erkl\u00e4ren"], "yaxis": "y7"}, {"marker": {"color": "#b26363"}, "name": "Nordamerika", "orientation": "h", "type": "bar", "x": [275, 178, 164, 148, 124, 112, 94, 87, 82, 80, 79, 73, 66, 63, 63, 62, 62, 60, 57, 57], "xaxis": "x8", "y": ["werden", "Trump", "sein", "Jahr", "USA", "the", "sagen", "to", "a", "Polizei", "and", "erkl\u00e4ren", "of", "mehr", "geben", "kommen", "Million", "seit", "Donald", "Pr\u00e4sident"], "yaxis": "y8"}, {"marker": {"color": "#ec8c16"}, "name": "Amerika", "orientation": "h ...

# %%
# Visualize: most common trigrams of each category

gesellschaft = trigram_df[trigram_df['Category'] == 'gesellschaft']
wirtschaft = trigram_df[trigram_df['Category'] == 'wirtschaft']
inland =  trigram_df[trigram_df['Category'] == 'inland']
asien =  trigram_df[trigram_df['Category'] == 'asien']
amerika =  trigram_df[trigram_df['Category'] == 'amerika']
nordamerika = trigram_df[trigram_df['Category'] == 'nordamerika']
europa =  trigram_df[trigram_df['Category'] == 'europa']
der_nahe_osten =  trigram_df[trigram_df['Category'] == 'der-nahe-osten']
afrika =  trigram_df[trigram_df['Category'] == 'afrika']
russland =  trigram_df[trigram_df['Category'] == 'russland']


gesellschaft = go.Bar(y=gesellschaft['Most common trigram'], x=gesellschaft['Count Trigram'],
            marker=dict(color="#f3f416"), orientation='h', name='Gesellschaft')

wirtschaft = go.Bar(y=wirtschaft['Most common trigram'], x=wirtschaft['Count Trigram'],
            marker=dict(color="#19d4c6"), orientation='h', name='Wirtschaft')

inland = go.Bar(y=inland['Most common trigram'], x=inland['Count Trigram'],
            marker=dict(color="#211bc9"), orientation='h', name='Inland')

asien = go.Bar(y=asien['Most common trigram'], x=asien['Count Trigram'],
            marker=dict(color="#b416c7"), orientation='h', name='Asien')

amerika = go.Bar(y=amerika['Most common trigram'], x=amerika['Count Trigram'],
            marker=dict(color="#ec8c16"), orientation='h', name='Amerika')

nordamerika = go.Bar(y=nordamerika['Most common trigram'], x=nordamerika['Count Trigram'],
            marker=dict(color="#b26363"), orientation='h',name='Nordamerika')

europa = go.Bar(y=europa['Most common trigram'],x=europa['Count Trigram'],
            marker=dict(color="#20d62c"), orientation='h', name='Europa')

der_nahe_osten = go.Bar(y=der_nahe_osten['Most common trigram'], x=der_nahe_osten['Count Trigram'],
            marker=dict(color="#d41763"), orientation='h', name='Der nahe Osten')

afrika = go.Bar(y=afrika['Most common trigram'], x=afrika['Count Trigram'],
            marker=dict(color="#a72727"), orientation='h', name='Afrika')

russland = go.Bar(y=russland['Most common trigram'], x=russland['Count Trigram'],
            marker=dict(color="#458b74"), orientation='h', name='Russland')




fig = plotly.subplots.make_subplots(rows=10, cols=1)

fig.append_trace(gesellschaft, 1,1)
fig.append_trace(wirtschaft, 2, 1)
fig.append_trace(inland, 3,1)
fig.append_trace(europa, 4, 1)
fig.append_trace(asien, 5,1)
fig.append_trace(der_nahe_osten, 6, 1)
fig.append_trace(russland, 7,1)
fig.append_trace(nordamerika, 8, 1)
fig.append_trace(amerika, 9,1)
fig.append_trace(afrika, 10, 1)


fig.update_yaxes(title_text='<b>Most common Trigrams</b>')
fig.update_xaxes(title_text='<b>Trigram Count</b>')

fig.update_layout(height=5000, width=1000,
                  title_text='<b>Most common Trigrams of RT News Articles (German) by Category</b>', # title of plot
                  # gap between bars of adjacent location coordinates
                  bargap=0.3,
                  # gap between bars of the same location coordinates
                  bargroupgap=0.1)




fig.show()
# Out:
# <div>                            <div id="38f441aa-95db-4357-b8eb-f674bbf1c6d6" class="plotly-graph-div" style="height:5000px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("38f441aa-95db-4357-b8eb-f674bbf1c6d6")) {                    Plotly.newPlot(                        "38f441aa-95db-4357-b8eb-f674bbf1c6d6",                        [{"marker": {"color": "#f3f416"}, "name": "Gesellschaft", "orientation": "h", "type": "bar", "x": [15, 12, 9, 8, 8, 8, 7, 7, 7, 7, 7, 6, 6, 6, 6, 6, 6, 6, 6, 6], "xaxis": "x", "y": ["in den USA", "so der Ausschuss", "in der CoronaKrise", "Das ist eine", "dass es sich", "und so weiter", "infolge der CoronaMa\u00dfnahmen", "in der Lage", "darauf hin dass", "den sozialen Medien", "in einem Interview", "der Kinder und", "Kinder und Jugendlichen", "auf der Erde", "dass sie sich", "in den erJahren", "in den sozialen", "in den vergangenen", "gibt es keine", "und in der"], "yaxis": "y"}, {"marker": {"color": "#19d4c6"}, "name": "Wirtschaft", "orientation": "h", "type": "bar", "x": [39, 36, 24, 18, 17, 15, 13, 13, 12, 12, 11, 11, 11, 10, 10, 10, 9, 9, 8, 8], "xaxis": "x2", "y": ["Barrel pro Tag", "Millionen Barrel pro", "in den USA", "in diesem Jahr", "von Milliarden USDollar", "im Zusammenhang mit", "darauf hin dass", "auf Millionen Barrel", "f\u00fcgte hinzu dass", "im Vergleich zum", "den USA und", "zwischen den beiden", "im zweiten Quartal", "mehr als Prozent", "davon aus dass", "um Millionen Barrel", "in H\u00f6he von", "im Wert von", "zwischen den USA", "USA und China"], "yaxis": "y2"}, {"marker": {"color": "#211bc9"}, "name": "Inland", "orientation": "h", "type": "bar", "x": [13, 11, 9, 9, 8, 8, 8, 8, 8, 8, 7, 7, 7, 7, 7, 6, 6, 6, 6, 6], "xaxis": "x3", "y": ["gegen die CoronaMa\u00dfnahmen", "der Initiative Querdenken", "Sturm auf den", "von Nord Stream", "in der CoronaKrise", "der russischen Regierung", "Au\u00dfenminister Heiko Maas", "an der Siegess\u00e4ule", "auf der Stra\u00dfe", "gegen die CoronaPolitik", "auf den Reichstag", "vor dem Reichstag", "die russische Regierung", "im Fall Nawalny", "Innensenator Andreas Geisel", "Angaben der Polizei", "es sich bei", "der Kinder und", "es sich um", "von der Polizei"], "yaxis": "y3"}, {"marker": {"color": "#20d62c"}, "name": "Europa", "orientation": "h", "type": "bar", "x": [21, 10, 9, 9, 9, 8, 8, 8, 8, 7, 7, 7, 7, 7, 7, 7, 6, 6, 6, 6], "xaxis": "x4", "y": ["im \u00f6stlichen Mittelmeer", "in der Region", "von Alexei Nawalny", "im vergangenen Jahr", "in der \u00c4g\u00e4is", "Bundeskanzlerin Angela Merkel", "der Europ\u00e4ischen Union", "nach wie vor", "auf die Stra\u00dfe", "in den letzten", "Nawalny mit einem", "nach eigenen Angaben", "an der Macht", "im Zusammenhang mit", "zwischen den beiden", "Prozent der Stimmen", "als auch die", "aus der NowitschokGruppe", "der NowitschokGruppe vergiftet", "aus dem Ausland"], "yaxis": "y4"}, {"marker": {"color": "#b416c7"}, "name": "Asien", "orientation": "h", "type": "bar", "x": [13, 12, 11, 11, 10, 9, 9, 9, 9, 8, 7, 7, 7, 7, 7, 7, 7, 7, 6, 6], "xaxis": "x5", "y": ["f\u00fcgte hinzu dass", "in der Region", "an der Grenze", "zwischen den beiden", "darauf hin dass", "im Zusammenhang mit", "Nach Angaben der", "in einer Erkl\u00e4rung", "im S\u00fcdchinesischen Meer", "in den USA", "den Vereinigten Staaten", "des chinesischen Au\u00dfenministeriums", "hie\u00df es in", "die Zahl der", "zwischen China und", "in Bezug auf", "den beiden L\u00e4ndern", "Trump und Kim", "auf dem Weg", "den USA und"], "yaxis": "y5"}, {"marker": {"color": "#d41763"}, "name": "Der nahe Osten", "orientation": "h", "type": "bar", "x": [33, 29, 24, 18, 17, 15, 15, 15, 14, 14, 14, 13, 13, 13, 12, 12, 12, 11, 10, 10], "xaxis": "x6", "y": ["Hafen von Beirut", "in der Region", "im Hafen von", "Vereinigten Arabischen Emirate", "zwischen Israel und", "V ...
